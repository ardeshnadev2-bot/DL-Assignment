# %% [markdown]
# QUE : 1 -->
#
# Create a Python script that loads a sample image (use any image of your favorite cricketer or celebrity), converts it to a NumPy array, and prints the array shape to demonstrate how images are represented for CNNs.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = Image.open("virat_kohli.jpg")   # Replace with your image file name

# Convert image to NumPy array
image_array = np.array(image)

# Print information
print("Image Shape:", image_array.shape)
print("Data Type:", image_array.dtype)

# Display the image
plt.imshow(image_array)
plt.title("Sample Image")
plt.axis("off")
plt.show()

# %% [markdown]
# QUE : 2 -->
#
# Implement a simple 2D convolution operation in Python using NumPy: given a 5x5 grayscale image array and a 3x3 filter, compute the output feature map without using any deep learning libraries.<br><br><em><strong>Hint:</strong> Use nested loops to slide the filter over the image and sum the element-wise products.</em>

# %%
import numpy as np

# 5x5 Grayscale Image
image = np.array([
    [1, 2, 3, 0, 1],
    [4, 5, 6, 1, 2],
    [7, 8, 9, 2, 3],
    [1, 2, 3, 4, 5],
    [6, 7, 8, 9, 0]
])

# 3x3 Filter (Kernel)
kernel = np.array([
    [1, 0, -1],
    [1, 0, -1],
    [1, 0, -1]
])

# Dimensions
image_height, image_width = image.shape
kernel_height, kernel_width = kernel.shape

# Output Feature Map Size
output_height = image_height - kernel_height + 1
output_width = image_width - kernel_width + 1

# Initialize Output Feature Map
feature_map = np.zeros((output_height, output_width))

# Perform Convolution
for i in range(output_height):
    for j in range(output_width):
        region = image[i:i+kernel_height, j:j+kernel_width]
        feature_map[i, j] = np.sum(region * kernel)

# Display Results
print("Input Image:")
print(image)

print("\nKernel:")
print(kernel)

print("\nOutput Feature Map:")
print(feature_map)

# %% [markdown]
# QUE : 3 -->
#
# Draw the architecture diagram of a basic CNN (on paper or using a tool like draw.io) showing input layer, one convolutional layer, one pooling layer, and an output layer. Label each part and briefly describe its function in 1-2 lines.

# %%
+------------------+      +----------------------+      +------------------+      +------------------+
|   Input Image    | ---> | Convolution Layer    | ---> |  Pooling Layer   | ---> |   Output Layer   |
|   (32×32×3 RGB)  |      | (3×3 Filter + ReLU)  |      |   (2×2 MaxPool)  |      | (Classification) |
+------------------+      +----------------------+      +------------------+      +------------------+


| Layer                 | Function                                                                                                                                                       |
| --------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------- |
| **Input Layer**       | Receives the original image as input. The image is represented as a matrix of pixel values (e.g., 32 × 32 × 3 for an RGB image).                               |
| **Convolution Layer** | Applies filters (kernels) to detect important features such as edges, textures, and shapes. The ReLU activation function introduces non-linearity.             |
| **Pooling Layer**     | Reduces the size of the feature maps by keeping the most important information (e.g., Max Pooling), which decreases computation and helps prevent overfitting. |
| **Output Layer**      | Produces the final prediction by classifying the image into one of the predefined categories (e.g., Cat, Dog, Car, etc.).                                      |


Input Image
     │
     ▼
+------------------+
|   Input Layer    |
+------------------+
     │
     ▼
+---------------------------+
| Convolution Layer (3×3)   |
| + ReLU Activation         |
+---------------------------+
     │
     ▼
+------------------+
| Max Pooling 2×2  |
+------------------+
     │
     ▼
+------------------+
|  Output Layer    |
|  Classification  |
+------------------+

# %% [markdown]
# QUE : 4 -->
#
# Write a function in Python that takes an image array and returns a new array where each pixel is replaced by the maximum value in its 2x2 local neighborhood (simulate max pooling).<br><br><em><strong>Constraint:</strong> Do not use any deep learning libraries like TensorFlow or PyTorch for this task.</em>

# %%
import numpy as np

# Function to perform 2x2 Max Pooling
def max_pooling(image):
    rows, cols = image.shape

    # Output size after 2x2 pooling with stride 2
    pooled_rows = rows // 2
    pooled_cols = cols // 2

    pooled_image = np.zeros((pooled_rows, pooled_cols), dtype=image.dtype)

    # Perform max pooling
    for i in range(pooled_rows):
        for j in range(pooled_cols):
            region = image[i*2:i*2+2, j*2:j*2+2]
            pooled_image[i, j] = np.max(region)

    return pooled_image

# Sample 4x4 grayscale image
image = np.array([
    [1, 3, 2, 4],
    [5, 6, 1, 2],
    [7, 8, 9, 3],
    [4, 2, 5, 6]
])

# Apply max pooling
output = max_pooling(image)

# Display results
print("Original Image:")
print(image)

print("\nPooled Image:")
print(output)

# %% [markdown]
# QUE : 5 -->
#
# Explain with a real-world example from Instagram or Zomato how translation invariance in CNNs is useful. Write 2-3 sentences connecting it to how these apps recognize faces or food items even if they appear in different positions in the image.
#
# -->Translation invariance in CNNs allows the model to recognize the same object even if it appears in different positions within an image. For example, Instagram can detect and recognize a person's face whether it is in the center, corner, or side of a photo for features like face tagging. Similarly, Zomato can identify a food item from an uploaded image even if the dish is placed at the top, bottom, or any other location in the picture, making image recognition more accurate and reliable.
